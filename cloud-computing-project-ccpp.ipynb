# %%
import os
import boto3
import re
import sagemaker


role = sagemaker.get_execution_role()
region = boto3.Session().region_name

# S3 bucket for training data.
# Feel free to specify a different bucket and prefix.
data_bucket = sagemaker.Session().default_bucket()
data_prefix = "sagemaker/linear-learner-regression-ccpp"


# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket and prefix
output_bucket = sagemaker.Session().default_bucket()
output_prefix = "linear-learner-regression-ccpp"

# %%
# %%time

import io
import boto3
import random

# Load the dataset
FILE_DATA = "Folds5x2_pp.csv"

# split the downloaded data into train/test/validation files
FILE_TRAIN = "ccpp_dataset1_train.csv"
FILE_VALIDATION = "ccpp_dataset1_validation.csv"
FILE_TEST = "ccpp_dataset1_test.csv"
PERCENT_TRAIN = 70
PERCENT_VALIDATION = 15
PERCENT_TEST = 15

def data_split(
    FILE_DATA, FILE_TRAIN, FILE_VALIDATION, FILE_TEST, PERCENT_TRAIN, PERCENT_VALIDATION, PERCENT_TEST
):
    data = [l for l in open(FILE_DATA, "r")]
    train_file = open(FILE_TRAIN, "w")
    valid_file = open(FILE_VALIDATION, "w")
    tests_file = open(FILE_TEST, "w")

    num_of_data = len(data)
    num_train = int((PERCENT_TRAIN / 100.0) * num_of_data)
    num_valid = int((PERCENT_VALIDATION / 100.0) * num_of_data)
    num_tests = int((PERCENT_TEST / 100.0) * num_of_data)

    data_fractions = [num_train, num_valid, num_tests]
    split_data = [[], [], []]

    rand_data_ind = 0

    for split_ind, fraction in enumerate(data_fractions):
        for i in range(fraction):
            rand_data_ind = random.randint(0, len(data) - 1)
            split_data[split_ind].append(data[rand_data_ind])
            data.pop(rand_data_ind)

    for l in split_data[0]:
        train_file.write(l)

    for l in split_data[1]:
        valid_file.write(l)

    for l in split_data[2]:
        tests_file.write(l)

    train_file.close()
    valid_file.close()
    tests_file.close()
    
data_split(
    FILE_DATA, FILE_TRAIN, FILE_VALIDATION, FILE_TEST, PERCENT_TRAIN, PERCENT_VALIDATION, PERCENT_TEST
)

# S3 bucket to store training data.
# Feel free to specify a different bucket and prefix.
bucket = sagemaker.Session().default_bucket()
prefix = "sagemaker/linear-learner-regression-ccpp"

def write_to_s3(fobj, bucket, key):
    return (
        boto3.Session(region_name=region).resource("s3").Bucket(bucket).Object(key).upload_fileobj(fobj)
    )


def upload_to_s3(bucket, prefix, channel, filename):
    fobj = open(filename, "rb")
    key = f"{prefix}/{channel}/{filename}"
    url = f"s3://{bucket}/{key}"
    print(f"Writing to {url}")
    write_to_s3(fobj, bucket, key)
    
# upload the files to the S3 bucket
upload_to_s3(bucket, prefix, "train", FILE_TRAIN)
upload_to_s3(bucket, prefix, "validation", FILE_VALIDATION)
upload_to_s3(bucket, prefix, "test", FILE_TEST)
# Out:
# Writing to s3://sagemaker-us-east-1-872507569564/sagemaker/linear-learner-regression-ccpp/train/ccpp_dataset1_train.csv
# Writing to s3://sagemaker-us-east-1-872507569564/sagemaker/linear-learner-regression-ccpp/validation/ccpp_dataset1_validation.csv
# Writing to s3://sagemaker-us-east-1-872507569564/sagemaker/linear-learner-regression-ccpp/test/ccpp_dataset1_test.csv
# CPU times: user 298 ms, sys: 31 ms, total: 329 ms
# Wall time: 822 ms

# %%
FILE_TRAIN = "ccpp_dataset1_train.csv"
s3 = boto3.client("s3")
s3.download_file(data_bucket, f"{data_prefix}/train/{FILE_TRAIN}", FILE_TRAIN)

import pandas as pd  # Read in csv and store in a pandas dataframe

df = pd.read_csv(FILE_TRAIN, sep=",", encoding="latin1", names=["PE","AT","V","AP","RH"])
print(df.head(2))
# Out:
#        PE     AT      V       AP     RH
# 0  441.12  26.96  72.86  1004.86  59.17
# 1  489.36   5.51  35.57  1026.30  78.97

# %%
# creating the inputs for the fit() function with the training and validation location
s3_train_data = f"s3://{data_bucket}/{data_prefix}/train"
print(f"training files will be taken from: {s3_train_data}")
s3_validation_data = f"s3://{data_bucket}/{data_prefix}/validation"
print(f"validtion files will be taken from: {s3_validation_data}")
output_location = f"s3://{output_bucket}/{output_prefix}/output"
print(f"training artifacts output location: {output_location}")

# generating the session.s3_input() format for fit() accepted by the sdk
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
# Out:
# training files will be taken from: s3://sagemaker-us-east-1-872507569564/sagemaker/linear-learner-regression-ccpp/train
# validtion files will be taken from: s3://sagemaker-us-east-1-872507569564/sagemaker/linear-learner-regression-ccpp/validation
# training artifacts output location: s3://sagemaker-us-east-1-872507569564/linear-learner-regression-ccpp/output

# %%
# getting the linear learner image according to the region
from sagemaker.image_uris import retrieve

container = retrieve("linear-learner", boto3.Session().region_name, version="1")
print(container)
# Out:
# 382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1

# %%
# %%time

from time import gmtime, strftime

sess = sagemaker.Session()

job_name = "linear-learner-regression-ccpp-" + strftime("%H-%M-%S", gmtime())
print("Training job", job_name)

linear = sagemaker.estimator.Estimator(
    container,
    role,
    input_mode="File",
    instance_count=1,
    instance_type="ml.c4.xlarge",
    output_path=output_location,
    sagemaker_session=sess,
)

linear.set_hyperparameters(
    feature_dim=4,
    epochs=16,
    wd=0.01,
    loss="absolute_loss",
    predictor_type="regressor",
    normalize_data=True,
    optimizer="adam",
    mini_batch_size=100,
    lr_scheduler_step=100,
    lr_scheduler_factor=0.99,
    lr_scheduler_minimum_lr=0.0001,
    learning_rate=0.1,
)
# Out:
# Training job linear-learner-regression-ccpp-21-21-31
# CPU times: user 11.1 ms, sys: 4.17 ms, total: 15.2 ms
# Wall time: 14.5 ms

# %%
# %%time
linear.fit(inputs={"train": train_data, "validation": validation_data}, job_name=job_name)
# Out:
# 2021-01-12 21:21:35 Starting - Starting the training job...
# 2021-01-12 21:21:58 Starting - Launching requested ML instancesProfilerReport-1610486494: InProgress
# .........
# 2021-01-12 21:23:19 Starting - Preparing the instances for training.........
# 2021-01-12 21:25:01 Downloading - Downloading input data
# 2021-01-12 21:25:01 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/12/2021 21:25:21 INFO 139896050251584] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/12/2021 21:25:21 INFO 139896050251584] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'absolute_loss', u'wd': u'0.01', u'optimizer': u'adam', u'predictor_type': u'regressor', u'epochs': u'16', u'normalize_data': u'True', u'lr_scheduler_step': u'100', u'feature_dim': u'4', u'lr_scheduler_factor': u'0.99', u'mini_batch_size': u'100', u'learning_rate': u'0.1', u'lr_scheduler_minimum_lr': u'0.0001'}
# [01/12/2021 21:25:21 INFO 139896050251584] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'16', u'feature_dim': u'4', u'init_bias': u'0.0', u'lr_scheduler_factor': u'0.99', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'100', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'0.0001', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'0.01', u'optimizer': u'adam', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'0.1', u'_kvstore': u'auto', u'normalize_data': u'True', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'100', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'absolute_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/12/2021 21:25:21 WARNING 139896050251584] Loggers have already been setup.
# Process 1 is a worker.
# [01/12/2021 21:25:21 INFO 139896050251584] Using default worker.
# [01/12/2021 21:25:21 INFO 139896050251584] Checkpoint loading and saving are disabled.
# [01/12/2021 21:25:21 INFO 139896050251584] Create Store: local
#
# 2021-01-12 21:25:21 Training - Training image download completed. Training in progress.[01/12/2021 21:25:21 INFO 139896050251584] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3bb6e340d0>
# [01/12/2021 21:25:21 INFO 139896050251584] Scaling model computed with parameters:
#  {'stdev_weight':
# [ 7.4754496 12.715361   5.9189754 14.577071 ]
# <NDArray 4 @cpu(0)>, 'stdev_label':
# [17.104673]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [454.4262]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [  19.615486   54.294727 1013.28784    73.45907 ]
# <NDArray 4 @cpu(0)>}
# [01/12/2021 21:25:21 INFO 139896050251584] nvidia-smi took: 0.0251860618591 secs to identify 0 gpus
# [01/12/2021 21:25:21 INFO 139896050251584] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 67, "sum": 67.0, "min": 67}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Total Records Seen": {"count": 1, "max": 6797, "sum": 6797.0, "min": 6797}, "Max Records Seen Between Resets": {"count": 1, "max": 6697, "sum": 6697.0, "min": 6697}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1610486721.972398, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1610486721.972334}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2839283628174753, "sum": 0.2839283628174753, "min": 0.2839283628174753}}, "EndTime": 1610486723.24682, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.246764}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5223930766365745, "sum": 0.5223930766365745, "min": 0.5223930766365745}}, "EndTime": 1610486723.246901, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.246883}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5668566472602613, "sum": 0.5668566472602613, "min": 0.5668566472602613}}, "EndTime": 1610486723.246962, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.246946}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5039242218479966, "sum": 0.5039242218479966, "min": 0.5039242218479966}}, "EndTime": 1610486723.247025, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247009}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.29287892746202876, "sum": 0.29287892746202876, "min": 0.29287892746202876}}, "EndTime": 1610486723.247094, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247078}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2795718577413848, "sum": 0.2795718577413848, "min": 0.2795718577413848}}, "EndTime": 1610486723.247152, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247137}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2953407981178977, "sum": 0.2953407981178977, "min": 0.2953407981178977}}, "EndTime": 1610486723.247216, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247199}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2816373536081025, "sum": 0.2816373536081025, "min": 0.2816373536081025}}, "EndTime": 1610486723.247276, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.24726}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5086007378318093, "sum": 0.5086007378318093, "min": 0.5086007378318093}}, "EndTime": 1610486723.247347, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247329}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5444649771488074, "sum": 0.5444649771488074, "min": 0.5444649771488074}}, "EndTime": 1610486723.247416, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247398}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5726994046297941, "sum": 0.5726994046297941, "min": 0.5726994046297941}}, "EndTime": 1610486723.247465, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.24745}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.5366725499702223, "sum": 0.5366725499702223, "min": 0.5366725499702223}}, "EndTime": 1610486723.247522, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247505}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.27973783059553664, "sum": 0.27973783059553664, "min": 0.27973783059553664}}, "EndTime": 1610486723.247591, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247573}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.28512398690888374, "sum": 0.28512398690888374, "min": 0.28512398690888374}}, "EndTime": 1610486723.247654, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247637}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.29310425816160257, "sum": 0.29310425816160257, "min": 0.29310425816160257}}, "EndTime": 1610486723.247726, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.247708}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0
"Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.44448}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.904477726208624, "sum": 5.904477726208624, "min": 5.904477726208624}}, "EndTime": 1610486723.444654, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444632}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 3.722285828274717, "sum": 3.722285828274717, "min": 3.722285828274717}}, "EndTime": 1610486723.444753, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444732}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 3.606451543615255, "sum": 3.606451543615255, "min": 3.606451543615255}}, "EndTime": 1610486723.444816, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444798}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 3.6569249595083844, "sum": 3.6569249595083844, "min": 3.6569249595083844}}, "EndTime": 1610486723.444884, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444866}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 3.8258920490118684, "sum": 3.8258920490118684, "min": 3.8258920490118684}}, "EndTime": 1610486723.444949, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444931}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.66956183137794, "sum": 5.66956183137794, "min": 5.66956183137794}}, "EndTime": 1610486723.445011, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.444994}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.722725111266877, "sum": 5.722725111266877, "min": 5.722725111266877}}, "EndTime": 1610486723.445079, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445061}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 6.1599942835365855, "sum": 6.1599942835365855, "min": 6.1599942835365855}}, "EndTime": 1610486723.44515, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445131}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 6.443282049624346, "sum": 6.443282049624346, "min": 6.443282049624346}}, "EndTime": 1610486723.44521, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445193}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.240816569577526, "sum": 5.240816569577526, "min": 5.240816569577526}}, "EndTime": 1610486723.445282, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445263}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.4708672393905164, "sum": 5.4708672393905164, "min": 5.4708672393905164}}, "EndTime": 1610486723.445343, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445327}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.883227071197191, "sum": 5.883227071197191, "min": 5.883227071197191}}, "EndTime": 1610486723.445402, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445385}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.657493479658918, "sum": 5.657493479658918, "min": 5.657493479658918}}, "EndTime": 1610486723.445471, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445453}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.429893509602298, "sum": 14.429893509602298, "min": 14.429893509602298}}, "EndTime": 1610486723.445532, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445516}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.477066773736933, "sum": 14.477066773736933, "min": 14.477066773736933}}, "EndTime": 1610486723.445592, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445576}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.439393004307764, "sum": 14.439393004307764, "min": 14.439393004307764}}, "EndTime": 1610486723.445652, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445636}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.407498349711455, "sum": 14.407498349711455, "min": 14.407498349711455}}, "EndTime": 1610486723.445716, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445699}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.59079944996053, "sum": 14.59079944996053, "min": 14.59079944996053}}, "EndTime": 1610486723.44578, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445762}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.665958183899988, "sum": 14.665958183899988, "min": 14.665958183899988}}, "EndTime": 1610486723.44584, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445824}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.65062885350882, "sum": 14.65062885350882, "min": 14.65062885350882}}, "EndTime": 1610486723.445901, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445885}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.616381687071264, "sum": 14.616381687071264, "min": 14.616381687071264}}, "EndTime": 1610486723.445972, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1610486723.445955}
#
# [01/12/2021 21:25:23 INFO 139896050251584] #quality_metric: host=algo-1, epoch=0, validation absolute_loss_objective <loss>=3.80401188123
# [01/12/2021 21:25:23 INFO 139896050251584] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=3.60645154362
# [01/12/2021 21:25:23 INFO 139896050251584] Epoch 0: Loss improved. Updating best model
# [01/12/2021 21:25:23 INFO 139896050251584] Saving model for epoch: 0
# [01/12/2021 21:25:23 INFO 139896050251584] Saved checkpoint to "/tmp/tmpBqWf7e/mx-mod-0000.params"
# [01/12/2021 21:25:23 INFO 139896050251584] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 67, "sum": 67.0, "min": 67}, "Number of Batches Since Last Reset": {"count": 1, "max": 67, "sum": 67.0, "min": 67}, "Number of Records Since Last Reset": {"count": 1, "max": 6697, "sum": 6697.0, "min": 6697}, "Total Batches Seen": {"count": 1, "max": 135, "sum": 135.0, "min": 135}, "Total Records Seen": {"count": 1, "max": 13494, "sum": 13494.0, "min": 13494}, "Max Records Seen Between Resets": {"count": 1, "max": 6697, "sum": 6697.0, "min": 6697}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 
"Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792484}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 4.977535298310921, "sum": 4.977535298310921, "min": 4.977535298310921}}, "EndTime": 1610486745.792566, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792548}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.0466856846826005, "sum": 5.0466856846826005, "min": 5.0466856846826005}}, "EndTime": 1610486745.792627, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792609}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.174553039763447, "sum": 5.174553039763447, "min": 5.174553039763447}}, "EndTime": 1610486745.792715, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792696}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 4.9946999367105835, "sum": 4.9946999367105835, "min": 4.9946999367105835}}, "EndTime": 1610486745.792768, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792757}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 5.480385129709277, "sum": 5.480385129709277, "min": 5.480385129709277}}, "EndTime": 1610486745.792828, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792811}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.443496459535606, "sum": 14.443496459535606, "min": 14.443496459535606}}, "EndTime": 1610486745.792896, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792878}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.425640443808526, "sum": 14.425640443808526, "min": 14.425640443808526}}, "EndTime": 1610486745.792959, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.792942}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.430824540301067, "sum": 14.430824540301067, "min": 14.430824540301067}}, "EndTime": 1610486745.793022, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.793005}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.433186728447572, "sum": 14.433186728447572, "min": 14.433186728447572}}, "EndTime": 1610486745.793082, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.79307}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.543074019694577, "sum": 14.543074019694577, "min": 14.543074019694577}}, "EndTime": 1610486745.793137, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.793121}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.605420985205248, "sum": 14.605420985205248, "min": 14.605420985205248}}, "EndTime": 1610486745.793185, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.793175}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.545045114975773, "sum": 14.545045114975773, "min": 14.545045114975773}}, "EndTime": 1610486745.793214, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.793207}
#
# #metrics {"Metrics": {"validation_absolute_loss_objective": {"count": 1, "max": 14.741634121672202, "sum": 14.741634121672202, "min": 14.741634121672202}}, "EndTime": 1610486745.793257, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486745.793242}
#
# [01/12/2021 21:25:45 INFO 139896050251584] #quality_metric: host=algo-1, epoch=15, validation absolute_loss_objective <loss>=3.85756217079
# [01/12/2021 21:25:45 INFO 139896050251584] #early_stopping_criteria_metric: host=algo-1, epoch=15, criteria=absolute_loss_objective, value=3.58662177428
# [01/12/2021 21:25:45 INFO 139896050251584] Saving model for epoch: 15
# [01/12/2021 21:25:45 INFO 139896050251584] Saved checkpoint to "/tmp/tmpSnz5Tf/mx-mod-0000.params"
# [01/12/2021 21:25:45 INFO 139896050251584] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 67, "sum": 67.0, "min": 67}, "Number of Batches Since Last Reset": {"count": 1, "max": 67, "sum": 67.0, "min": 67}, "Number of Records Since Last Reset": {"count": 1, "max": 6697, "sum": 6697.0, "min": 6697}, "Total Batches Seen": {"count": 1, "max": 1140, "sum": 1140.0, "min": 1140}, "Total Records Seen": {"count": 1, "max": 113949, "sum": 113949.0, "min": 113949}, "Max Records Seen Between Resets": {"count": 1, "max": 6697, "sum": 6697.0, "min": 6697}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1610486745.798221, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 15}, "StartTime": 1610486744.235639}
#
# [01/12/2021 21:25:45 INFO 139896050251584] #throughput_metric: host=algo-1, train throughput=4285.5503223 records/second
# [01/12/2021 21:25:45 WARNING 139896050251584] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/12/2021 21:25:45 WARNING 139896050251584] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/12/2021 21:25:45 INFO 139896050251584] #early_stopping_criteria_metric: host=algo-1, epoch=15, criteria=absolute_loss_objective, value=3.58662177428
# [01/12/2021 21:25:46 INFO 139896050251584] #validation_score (algo-1) : ('absolute_loss_objective', 3.5906091776459057)
# [01/12/2021 21:25:46 INFO 139896050251584] #validation_score (algo-1) : ('mse', 20.422987094573443)
# [01/12/2021 21:25:46 INFO 139896050251584] #validation_score (algo-1) : ('absolute_loss', 3.5906091776459057)
# [01/12/2021 21:25:46 INFO 139896050251584] #quality_metric: host=algo-1, validation absolute_loss_objective <loss>=3.59060917765
# [01/12/2021 21:25:46 INFO 139896050251584] #quality_metric: host=algo-1, validation mse <loss>=20.4229870946
# [01/12/2021 21:25:46 INFO 139896050251584] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.59060917765
# [01/12/2021 21:25:46 INFO 139896050251584] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [01/12/2021 21:25:46 INFO 139896050251584] Saved checkpoint to "/tmp/tmp9qi3J1/mx-mod-0000.params"
# [01/12/2021 21:25:46 INFO 139896050251584] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 24965.574026107788, "sum": 24965.574026107788, "min": 24965.574026107788}, "finalize.time": {"count": 1, "max": 215.09408950805664, "sum": 215.09408950805664, "min": 215.09408950805664}, "initialize.time": {"count": 1, "max": 676.0070323944092, "sum": 676.0070323944092, "min": 676.0070323944092}, "check_early_stopping.time": {"count": 17, "max": 1.1150836944580078, "sum": 6.326913833618164, "min": 0.16498565673828125}, "setuptime": {"count": 1, "max": 26.200056076049805, "sum": 26.200056076049805, "min": 26.200056076049805}, "update.time": {"count": 16, "max": 1670.3479290008545, "sum": 23778.35726737976, "min": 1386.9099617004395}, "epochs": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1610486746.01847, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1610486721.296011}
#
#
# 2021-01-12 21:26:01 Uploading - Uploading generated training model
# 2021-01-12 21:26:01 Completed - Training job completed
# Training seconds: 78
# Billable seconds: 78
# CPU times: user 732 ms, sys: 68.1 ms, total: 800 ms
# Wall time: 4min 43s

# %%
# %%time
# creating the endpoint out of the trained model
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
print(f"\ncreated endpoint: {linear_predictor.endpoint_name}")
# Out:
# -------------------!
# created endpoint: linear-learner-2021-01-12-21-31-23-270
# CPU times: user 340 ms, sys: 9.67 ms, total: 350 ms
# Wall time: 9min 32s

# %%
# configure the predictor to accept to serialize csv input and parse the reposne as json
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

linear_predictor.serializer = CSVSerializer()
linear_predictor.deserializer = JSONDeserializer()

# %%
# %%time
import json
from itertools import islice
import math
import struct
import boto3
import random

# downloading the test file from data_bucket
FILE_TEST = "ccpp_dataset1_test.csv"
s3 = boto3.client("s3")
s3.download_file(data_bucket, f"{data_prefix}/test/{FILE_TEST}", FILE_TEST)

# getting testing sample from our test file
test_data = [l for l in open(FILE_TEST, "r")]
sample = random.choice(test_data).split(",")
actual_age = sample[0]
payload = sample[1:]  # removing actual age from the sample
payload = ",".join(map(str, payload))

# Invoke the predicor and analyise the result
result = linear_predictor.predict(payload)

# extracting the prediction value
result = round(float(result["predictions"][0]["score"]), 2)


accuracy = str(round(100 - ((abs(float(result) - float(actual_age)) / float(actual_age)) * 100), 2))
print(f"Actual power: {actual_age}\nPrediction: {result}\nAccuracy: {accuracy}")
# Out:
# Actual power: 440.13
# Prediction: 440.48
# Accuracy: 99.92
# CPU times: user 41.5 ms, sys: 0 ns, total: 41.5 ms
# Wall time: 164 ms

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint_name)
print(f"deleted {linear_predictor.endpoint_name} successfully!")
# Out:
# deleted linear-learner-2021-01-12-21-31-23-270 successfully!
